# %%
import os

import pandas as pd
import numpy as np
import sklearn

import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # read sample data

# %%
file_dir = "transient_timeDomain/"
sample_name = "1"
suffix = ".csv"
file_name = file_dir  + sample_name + suffix
sample_df = pd.read_csv(file_name)
print(sample_df.shape)
sample_df.head()
# Out:
# (100000, 4)
#    gateSignalVoltage  gateEmitterVoltage  collectorEmitterVoltage  \
# 0      -7.812531e-02           -0.234375                   4.5625
# 1      -7.812531e-02           -0.234375                   4.5625
# 2      -7.812531e-02           -0.234375                   4.6250
# 3      -3.072000e-07           -0.234375                   4.6250
# 4      -3.072000e-07           -0.234375                   4.5625
#
#    collectorEmitterCurrentSingal
# 0                      -0.015625
# 1                      -0.015625
# 2                       0.015625
# 3                       0.015625
# 4                       0.000000

# %% [markdown]
# # plot a sample data

# %%
# plot the time sequence parameter
plt.figure(figsize=(16, 12))
plt.subplot(221)
plt.plot(sample_df.index.values, sample_df.gateSignalVoltage.values)
plt.title('Gate Signal Voltage',fontsize ='xx-large' )
plt.xlabel('Time /second',fontsize ='xx-large')
plt.ylabel('Voltage /V',fontsize ='xx-large')
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.ylim([-20,30])
plt.tight_layout()
# plt.savefig( 'transient_picture/gateSignalVoltage'+sample_name+'.png')

plt.subplot(222)
plt.plot(sample_df.index.values, sample_df.gateEmitterVoltage.values)
plt.title('Gate Emitter Voltage',fontsize ='xx-large' )
plt.xlabel('Time /second',fontsize ='xx-large')
plt.ylabel('Voltage /V',fontsize ='xx-large')
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.ylim([-2,18])
plt.tight_layout()
# plt.savefig( 'transient_picture/gateEmitterVoltage'+sample_name+'.png')

# plot the time sequence parameter
plt.subplot(223)
plt.plot(sample_df.index.values, sample_df.collectorEmitterVoltage.values)
plt.title('Collector Emitter Voltage',fontsize ='xx-large' )
plt.xlabel('Time /second',fontsize ='xx-large')
plt.ylabel('Voltage /V',fontsize ='xx-large')
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.ylim([1,7])
plt.tight_layout()
# plt.savefig('transient_picture//collectorEmitterVoltage'+sample_name+'.png')

# collectorEmitterCurrentSingal
# plot the time sequence parameter
plt.subplot(224)
plt.plot(sample_df.index.values, sample_df.collectorEmitterCurrentSingal.values)
plt.title('Collector Emitter Current',fontsize ='xx-large' )
plt.xlabel('Time /second',fontsize ='xx-large')
plt.ylabel('Current /V',fontsize ='xx-large')
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.ylim([-3,10])
plt.tight_layout()
plt.savefig('transient_picture//'+sample_name+'.png')

# plt.clf()

# %% [markdown]
# # plot all data and save

# %%
plt.figure(figsize=(16, 12))
i = 1
file_forder = file_dir 
for (_ ,_ , process_files) in os.walk(file_forder):
    for file in process_files:
        sample_df = pd.read_csv(file_forder + file )
        sample_name = str(i)
        
        # plot the time sequence parameter
        plt.subplot(221)
        plt.plot(sample_df.index.values, sample_df.gateSignalVoltage.values)
        plt.title('Gate Signal Voltage',fontsize ='xx-large' )
        plt.xlabel('Time /second',fontsize ='xx-large')
        plt.ylabel('Voltage /V',fontsize ='xx-large')
        plt.xticks(fontsize=12)
        plt.yticks(fontsize=12)
        plt.ylim([-2,12])
        plt.tight_layout()
        # plt.savefig( 'transient_picture/gateSignalVoltage'+sample_name+'.png')

        plt.subplot(222)
        plt.plot(sample_df.index.values, sample_df.gateEmitterVoltage.values)
        plt.title('Gate Emitter Voltage',fontsize ='xx-large' )
        plt.xlabel('Time /second',fontsize ='xx-large')
        plt.ylabel('Voltage /V',fontsize ='xx-large')
        plt.xticks(fontsize=12)
        plt.yticks(fontsize=12)
        plt.ylim([-2,12])
        plt.tight_layout()
        # plt.savefig( 'transient_picture/gateEmitterVoltage'+sample_name+'.png')

        # plot the time sequence parameter
        plt.subplot(223)
        plt.plot(sample_df.index.values, sample_df.collectorEmitterVoltage.values)
        plt.title('Collector Emitter Voltage',fontsize ='xx-large' )
        plt.xlabel('Time /second',fontsize ='xx-large')
        plt.ylabel('Voltage /V',fontsize ='xx-large')
        plt.xticks(fontsize=12)
        plt.yticks(fontsize=12)
        plt.ylim([-2,12])
        plt.tight_layout()
        # plt.savefig('transient_picture//collectorEmitterVoltage'+sample_name+'.png')

        # collectorEmitterCurrentSingal
        # plot the time sequence parameter
        plt.subplot(224)
        plt.plot(sample_df.index.values, sample_df.collectorEmitterCurrentSingal.values)
        plt.title('Collector Emitter Current',fontsize ='xx-large' )
        plt.xlabel('Time /second',fontsize ='xx-large')
        plt.ylabel('Current /V',fontsize ='xx-large')
        plt.xticks(fontsize=12)
        plt.yticks(fontsize=12)
        plt.ylim([-2,12])
        plt.tight_layout()
        plt.savefig('transient_picture//'+sample_name+'.png')

        plt.clf()
        
        i = i + 1

# %%
plt.figure(figsize=(16, 12))
i = 1
file_forder = "transient_timeDomain_cut/" 
for (_ ,_ , process_files) in os.walk(file_forder):
    for file in process_files:
        sample_df = pd.read_csv(file_forder + file )
        sample_name = str(i)
        
        # plot the time sequence parameter
        plt.subplot(221)
        plt.plot(sample_df.index.values, sample_df.gateSignalVoltage.values)
        plt.title('Gate Signal Voltage',fontsize ='xx-large' )
        plt.xlabel('Time /second',fontsize ='xx-large')
        plt.ylabel('Voltage /V',fontsize ='xx-large')
        plt.xticks(fontsize=12)
        plt.yticks(fontsize=12)
        plt.ylim([-2,12])
        plt.tight_layout()
        # plt.savefig( 'transient_picture/gateSignalVoltage'+sample_name+'.png')

        plt.subplot(222)
        plt.plot(sample_df.index.values, sample_df.gateEmitterVoltage.values)
        plt.title('Gate Emitter Voltage',fontsize ='xx-large' )
        plt.xlabel('Time /second',fontsize ='xx-large')
        plt.ylabel('Voltage /V',fontsize ='xx-large')
        plt.xticks(fontsize=12)
        plt.yticks(fontsize=12)
        plt.ylim([-2,12])
        plt.tight_layout()
        # plt.savefig( 'transient_picture/gateEmitterVoltage'+sample_name+'.png')

        # plot the time sequence parameter
        plt.subplot(223)
        plt.plot(sample_df.index.values, sample_df.collectorEmitterVoltage.values)
        plt.title('Collector Emitter Voltage',fontsize ='xx-large' )
        plt.xlabel('Time /second',fontsize ='xx-large')
        plt.ylabel('Voltage /V',fontsize ='xx-large')
        plt.xticks(fontsize=12)
        plt.yticks(fontsize=12)
        plt.ylim([-2,12])
        plt.tight_layout()
        # plt.savefig('transient_picture//collectorEmitterVoltage'+sample_name+'.png')

        # collectorEmitterCurrentSingal
        # plot the time sequence parameter
        plt.subplot(224)
        plt.plot(sample_df.index.values, sample_df.collectorEmitterCurrentSingal.values)
        plt.title('Collector Emitter Current',fontsize ='xx-large' )
        plt.xlabel('Time /second',fontsize ='xx-large')
        plt.ylabel('Current /V',fontsize ='xx-large')
        plt.xticks(fontsize=12)
        plt.yticks(fontsize=12)
        plt.ylim([-2,12])
        plt.tight_layout()
        plt.savefig('transient_picture_cut//'+sample_name+'.png')

        plt.clf()
        
        i = i + 1
