# %%
import os
from math import *

import numpy as np
import pandas as pd

import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
train_df = pd.read_csv('./data/train_feature_df.csv')
print(train_df.shape)
train_df.head()
# Out:
# (418, 162)
#    up_gateEmitterVoltage_min  up_gateEmitterVoltage_max  \
# 0                  -0.234375                   9.531250
# 1                  -0.312500                   9.609375
# 2                  -0.312500                   9.609375
# 3                  -0.312500                   9.609375
# 4                  -0.312500                   9.609375
#
#    up_gateEmitterVoltage_range  up_gateEmitterVoltage_mean  \
# 0                     9.765626                    6.751099
# 1                     9.921876                    6.669312
# 2                     9.921876                    6.631928
# 3                     9.921876                    6.625977
# 4                     9.921876                    6.607514
#
#    up_gateEmitterVoltage_mode  up_gateEmitterVoltage_median  \
# 0                      6.5625                      7.031250
# 1                      5.6250                      7.148438
# 2                      9.3750                      7.187500
# ...

# %%
# drop num_cycle < 28
train_df = train_df.iloc[ 28:,:]
train_df.to_csv("./temp/result_outlier.csv", index = False)
plt.figure(figsize = (16,5))
train_df.down_collectorEmitterVoltage_llr.plot()
